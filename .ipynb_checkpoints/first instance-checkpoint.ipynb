# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **My name is Aman**<br>I am a Student

# %% [markdown]
# *I am interested in data science because of the amazing prospect it is showing in IT field.*

# %% [markdown]
# In the cell below, the x is specified a fixed value then it is incremented by 1 and then print the value of x.

# %%
x = 6
x+=1
print(x)
# Out:
# 7

# %% [markdown]
# [I'm an inline-style link](https://www.google.com)<br>
# >This is a first line
# >
# >>This is a nested line
# >This is a last line<br>
#
# 1. First Item
# 2. Second Item
